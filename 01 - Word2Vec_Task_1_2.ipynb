# %% [markdown]
# # Word2Vec (Negative Sampling)
#
# Let's work on negative-sampling based implementation of word2vec.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import nltk
from nltk.corpus import reuters
import time

# %%
# NLTK data is downloade

nltk.download("reuters")
nltk.download("punkt_tab")
nltk.data.path.append('C:/Users/Arunya Senadeera/AppData/Roaming/nltk_data/tokenizers')
# Out:
# [nltk_data] Downloading package reuters to C:\Users\Arunya
# [nltk_data]     Senadeera\AppData\Roaming\nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Arunya
# [nltk_data]     Senadeera\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## 1. Define corpus data

# %%
# Prepare real-world corpus
# Corpus Creation
def prepare_corpus():
    corpus = [nltk.word_tokenize(reuters.raw(fileid)) for fileid in reuters.fileids()[:500]]
    return corpus

corpus = prepare_corpus()
print("Prepared Corpus Sample:", corpus[:5])
# Out:
# Prepared Corpus Sample: [['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U.S.-JAPAN', 'RIFT', 'Mounting', 'trade', 'friction', 'between', 'the', 'U.S.', 'And', 'Japan', 'has', 'raised', 'fears', 'among', 'many', 'of', 'Asia', "'s", 'exporting', 'nations', 'that', 'the', 'row', 'could', 'inflict', 'far-reaching', 'economic', 'damage', ',', 'businessmen', 'and', 'officials', 'said', '.', 'They', 'told', 'Reuter', 'correspondents', 'in', 'Asian', 'capitals', 'a', 'U.S.', 'Move', 'against', 'Japan', 'might', 'boost', 'protectionist', 'sentiment', 'in', 'the', 'U.S.', 'And', 'lead', 'to', 'curbs', 'on', 'American', 'imports', 'of', 'their', 'products', '.', 'But', 'some', 'exporters', 'said', 'that', 'while', 'the', 'conflict', 'would', 'hurt', 'them', 'in', 'the', 'long-run', ',', 'in', 'the', 'short-term', 'Tokyo', "'s", 'loss', 'might', 'be', 'their', 'gain', '.', 'The', 'U.S.', 'Has', 'said', 'it', 'will', 'impose', '300', 'mln', 'dlrs', 'of', 'tariffs', 'on', 'imports', 'of', 'Japanese', 'electronics', 'goods', 'on', 'April', '17', ',', 'in', 'retaliation', 'for', 'Japan', "'s", 'alleged', 'failure', 'to', 'stick', 'to', 'a', 'pact', 'not', 'to', 'sell', 'semiconductors', 'on', 'world', 'markets', 'at', 'below', 'cost', '.', 'Unofficial', 'Japanese', 'estimates', 'put', 'the', 'impact', 'of', 'the', 'tariffs', 'at', '10', 'billion', 'dlrs', 'and', 'spokesmen', 'for', 'major', 'electronics', 'firms', 'said', 'they', 'would', 'virtually', 'halt', 'exports', 'of', 'products', 'hit', 'by', 'the', 'new', 'taxes', '.', '``', 'We', 'would', "n't", 'be', 'able', 'to', 'do', 'business', ',', "''", 'said', 'a', 'spokesman', 'for', 'leading', 'Japanese', 'electronics', 'firm', 'Matsushita', 'Electric', 'Industrial', 'Co', 'Ltd', '&', 'lt', ';', 'MC.T', '>', '.', '``', 'If', 'the', 'tariffs', 'remain', 'in', 'place', 'for', 'any', 'length', 'of', 'time', 'beyond', 'a', 'few', 'months', 'it', 'will', 'mean', 'the', 'complete', 'erosion', 'of', 'exports', '(', 'of', 'goods', 'subject', 'to', 'tariffs', ')', 'to', 'the', 'U.S.', ',', "''", 'said', 'Tom', 'Murtha', ',', 'a', 'stock', 'analyst', 'at', 'the', 'Tokyo', 'office', 'of', 'broker', '&', 'lt', ';', 'James', 'Capel', 'and', 'Co', '>', '.', 'In', 'Taiwan', ',', 'businessmen', 'and', 'officials', 'are', 'also', 'worried', '.', '``', 'We', 'are', 'aware', 'of', 'the', 'seriousness', 'of', 'the', 'U.S', '.', 'Threat', 'against', 'Japan', 'because', 'it', 'serves', 'as', 'a', 'warning', 'to', 'us', ',', "''", 'said', 'a', 'senior', 'Taiwanese', 'trade', 'official', 'who', 'asked', 'not', 'to', 'be', 'named', '.', 'Taiwan', 'had', 'a', 'trade', 'trade', 'surplus', 'of', '15.6', 'billion', 'dlrs', 'last', 'year', ',', '95', 'pct', 'of', 'it', 'with', 'the', 'U.S', '.', 'The', 'surplus', 'helped', 'swell', 'Taiwan', "'s", 'foreign', 'exchange', 'reserves', 'to', '53', 'billion', 'dlrs', ',', 'among', 'the', 'world', "'s", 'largest', '.', '``', 'We', 'must', 'quickly', 'open', 'our', 'markets', ',', 'remove', 'trade', 'barriers', 'and', 'cut', 'import', 'tariffs', 'to', 'allow', 'imports', 'of', 'U.S.', 'Products', ',', 'if', 'we', 'want', 'to', 'defuse', 'problems', 'from', 'possible', 'U.S', '.', 'Retaliation', ',', "''", 'said', 'Paul', 'Sheen', ',', 'chairman', 'of', 'textile', 'exporters', '&', 'lt', ';', 'Taiwan', 'Safe', 'Group', '>', '.', 'A', 'senior', 'official', 'of', 'South', 'Korea', "'s", 'trade', 'promotion', 'association', 'said', 'the', 'trade', 'dispute', 'between', 'the', 'U.S.', 'And', 'Japan', 'might', 'also', 'lead', 'to', 'pressure', 'on', 'South', 'Korea', ',', 'whose', 'chief', 'exports', 'are', 'similar', 'to', 'those', 'of', 'Japan', '.', 'Last', 'year', 'South', 'Korea', 'had', 'a', 'trade', 'surplus', 'of', '7.1', 'billion', 'dlrs', 'with', 'the', 'U.S.', ',', 'Up', 'from', '4.9', 'billion', 'dlrs', 'in', '1985', '.', 'In', 'Malaysia', ',', 'trade', 'officers', 'and', 'businessmen', 'said', 'tough', 'curbs', 'against', 'Japan', 'might', 'allow', 'hard-hit', 'prod ...

# %%
# Flatten function
flatten = lambda l: [item for sublist in l for item in sublist]

# %%
#numericalization
corpus = prepare_corpus()
vocab = list(set(flatten(corpus)))

vocab.insert(0, "<UNK>")
word2index = {w: i for i, w in enumerate(vocab)}
index2word = {i: w for w, i in word2index.items()}
voc_size = len(vocab)

# %%
word2index = {w: i for i, w in enumerate(vocab)}
print(word2index)
# Out:
# {'<UNK>': 0, 'requirements': 1, 'Italian': 2, 'firmer': 3, 'Socialists': 4, 'boost': 5, '19': 6, 'FREE': 7, 'director-general': 8, 'FBOH': 9, '1.5': 10, '3,790,235': 11, 'BOVERI': 12, 'Gundy': 13, '2,468,000': 14, 'negatives': 15, '23.7': 16, 'actually': 17, 'Mij': 18, 'United': 19, '2107.64': 20, 'Food': 21, '130.9': 22, 'OPER': 23, 'problems': 24, 'significant': 25, 'dealing': 26, 'bacterium': 27, 'principal': 28, 'FLD': 29, 'ground': 30, '9.5': 31, 'more': 32, '2,536,896': 33, '9.6': 34, 'stable': 35, "''": 36, 'merchant': 37, 'Indonesia': 38, 'REVIVE': 39, 'focused': 40, 'downtrend': 41, 'Austwhim': 42, '662,647': 43, 'spokesman': 44, 'Vieille': 45, 'helping': 46, 'contravention': 47, '1409.50': 48, 'Darrell': 49, '100-dlr-a-share': 50, 'give': 51, '54.99': 52, 'Komatsu': 53, 'Hopes': 54, 'voting': 55, 'NON-DELHI': 56, 'introduce': 57, 'Yesterday': 58, 'poses': 59, 'influences': 60, '3,849,224': 61, '14.7': 62, 'sets': 63, 'avg': 64, 'blamed': 65, 'adoped': 66, 'pretax': 67, 'credit': 68, 'describes': 69, 'formula': 70, '113.0': 71, 'CRUDE': 72, 'GUAXUPE': 73, '787.9': 74, '15.66': 75, 'TREASURY': 76, 'microoganisms': 77, 'mid-1988': 78, 'soon': 79, 'Distillers': 80, 'electrical': 81, 'working': 82, 'transporting': 83, 'upturn': 84, 'tailored': 85, 'television': 86, 'Assets': 87, 'Reported': 88, 'Printing': 89, 'Milan-based': 90, '223.0': 91, 'WELCOMES': 92, 'MOTOR': 93, 'bookings': 94, '11:06:39.06': 95, 'one-time': 96, 'ITEMS': 97, 'Taiwanese': 98, 'lot': 99, 'associated': 100, '...........': 101, 'industrialized': 102, 'compromise': 103, 'UNEMPLOYMENT': 104, 'Medical': 105, '5/16': 106, 'excluding': 107, 'Iraqis': 108, 'REALTY': 109, 'SPOT': 110, 'Cereals': 111, 'branch': 112, '60.1': 113, 'retains': 114, 'Market': 115, 'HOMES': 116, 'crops': 117, 'growers': 118, '1.75': 119, 'orderly': 120, 'figures': 121, 'faked': 122, 'MINES': 123, 'buys': 124, 'retractable': 125, 'Carolina': 126, 'MADEIRA': 127, '82': 128, 'adequate': 129, 'feedstocks': 130, 'REPORTED': 131, 'Stauffer': 132, 'BUR': 133, 'institutions': 134, '3.75': 135, 'retaliate': 136, 'repoprt': 137, 'agenda': 138, '2867': 139, 'HOLDING': 140, '10.44': 141, 'do': 142, 'casualty': 143, 'prop': 144, 'morning': 145, 'operated': 146, 'muscle': 147, 'present': 148, 'HELEN': 149, 'pension': 150, 'GGFH': 151, 'fuller': 152, '1.1': 153, 'AG': 154, 'tomorrow': 155, 'DeKuyper': 156, 'collective': 157, 'headquarters': 158, '583': 159, 'wound': 160, 'hard': 161, '1.25': 162, 'hog': 163, 'BROKER': 164, '6-3/8': 165, 'SOUTHINGTON': 166, 'BOOMING': 167, 'AFBD': 168, 'damaged': 169, 'Conoco': 170, 'receipt': 171, '19.7': 172, 'PALLADIUM': 173, 'vigrously': 174, 'AVERAGE': 175, 'intermediate-term': 176, 'than': 177, 'de': 178, '265': 179, 'General': 180, 'fio': 181, 'Colonial': 182, 'commission': 183, '4,200': 184, '69.65': 185, 'growing': 186, 'entire': 187, 'asking': 188, 'HURTS': 189, '12.6': 190, 'IU': 191, 'mln': 192, 'Stearns': 193, 'you': 194, 'Burkhard': 195, 'arrangement': 196, 'Dec': 197, 'concerns': 198, '109.3': 199, '1993': 200, 'deals': 201, 'Todd': 202, 'moved': 203, 'Information': 204, 'timely': 205, 'Reuter': 206, 'typical': 207, '41': 208, '4,485,000': 209, 'Norway': 210, '105,000': 211, 'attractiveness': 212, 'Inc.': 213, 'beans': 214, 'unsolicted': 215, 'FLOUR': 216, '2,500': 217, 'external': 218, 'quietly': 219, 'AB': 220, 'Reader': 221, 'capitalizing': 222, 'Economists': 223, 'glamorous': 224, 'collateral': 225, 'grounds': 226, 'without': 227, 'distributions': 228, 'Murtha': 229, 'Elevator': 230, '2,000/2,000': 231, 'predecessor': 232, 'largely': 233, 'edged': 234, 'REPORTS': 235, 'NS/DNS': 236, 'D-Wis': 237, 'Goldman': 238, 'RBD': 239, 'Country': 240, 'months': 241, 'FOR': 242, '1.46': 243, 'March': 244, 'Heineken': 245, 'Natiionale': 246, 'favour': 247, 'life': 248, 'ECUS/TONNE': 249, 'benefit': 250, 'awards': 251, 'programme': 252, 'asked': 253, 'INTERSTATE': 254, '702,000': 255, 'FID': 256, 'SUPPLY': 257, 'using': 258, 'prospectus': 259, 'concrete': 260, ...

# %%
#vocab size
print(voc_size)
# Out:
# 10052

# %% [markdown]
# ## 2. Prepare train data

# %%
# Dynamic window size function
def random_batch(batch_size, word_sequence, window_size=2):
    skip_grams = []
    for sent in word_sequence:
        for i in range(len(sent)):
            target = word2index.get(sent[i], word2index["<UNK>"])
            context_indices = list(range(max(0, i - window_size), min(len(sent), i + window_size + 1)))
            context_indices.remove(i)
            context = [word2index.get(sent[j], word2index["<UNK>"]) for j in context_indices]
            for w in context:
                skip_grams.append([target, w])

    random_inputs = []
    random_labels = []
    random_index = np.random.choice(len(skip_grams), batch_size, replace=False)
    for i in random_index:
        random_inputs.append([skip_grams[i][0]])
        random_labels.append([skip_grams[i][1]])

    return np.array(random_inputs), np.array(random_labels)

# %% [markdown]
# ### Testing the method

# %%
#testing the method
batch_size = 2 # mini-batch size
input_batch, target_batch = random_batch(batch_size, corpus)

print("Input: ",  input_batch)
print("Target: ", target_batch)
input_batch.shape, target_batch.shape
# Out:
# Input:  [[2455]
#  [6649]]
# Target:  [[3082]
#  [3013]]
# ((2, 1), (2, 1))

# %% [markdown]
# ## 3. Negative Sampling

# %% [markdown]
# ### Unigram distribution
#
# $$P(w)=U(w)^{3/4}/Z$$

# %%
Z = 0.001
from collections import Counter

word_count = Counter(flatten(corpus))
num_total_words = sum([c for w, c in word_count.items()])

# %%
word_count[',']
# Out:
# 2614

# %%
num_total_words
# Out:
# 73442

# %%
unigram_table = []

for vo in vocab:
    unigram_table.extend([vo] * int(((word_count[vo]/num_total_words)**0.75)/Z))

# %%
Counter(unigram_table)
# Out:
# Counter({'the': 87,
#          ',': 81,
#          '.': 78,
#          'of': 61,
#          'to': 56,
#          'in': 47,
#          'said': 46,
#          'and': 44,
#          'a': 40,
#          'mln': 33,
#          'vs': 26,
#          'for': 25,
#          'The': 24,
#          "'s": 23,
#          'dlrs': 22,
#          'on': 20,
#          'it': 19,
#          '>': 19,
#          'is': 19,
#          'lt': 19,
#          ';': 19,
#          '&': 19,
#          'pct': 19,
#          'that': 18,
#          'its': 18,
#          "''": 17,
#          '``': 17,
#          'at': 17,
#          'from': 17,
#          'by': 17,
#          'cts': 17,
#          'was': 17,
#          'be': 16,
#          'year': 15,
#          'will': 14,
#          'billion': 14,
#          'with': 14,
#          'has': 14,
#          'not': 12,
#          'U.S.': 12,
#          'as': 12,
#          'an': 12,
#          'company': 12,
#          '1986': 11,
#          'would': 11,
#          'are': 11,
#          '(': 10,
#          'have': 10,
#          'which': 10,
#          ')': 10,
#          'he': 10,
#          'loss': 9,
#          'this': 9,
#          'market': 9,
#          'had': 9,
#          'Net': 9,
#          'last': 9,
#          'about': 8,
#          'they': 8,
#          'tonnes': 8,
#          'share': 8,
#          'Japan': 8,
#          'but': 8,
#          'been': 8,
#          'were': 8,
#          'or': 8,
#          'April': 8,
#          'shares': 8,
#          'also': 8,
#          'profit': 8,
#          'Shr': 8,
#          '1987': 7,
#          'trade': 7,
#          'quarter': 7,
#          'dollar': 7,
#          'TO': 7,
#          'QTR': 7,
#          'Inc': 7,
#          'more': 6,
#          'than': 6,
#          'stg': 6,
#          'In': 6,
#          'up': 6,
#          'Corp': 6,
#          'first': 6,
#          'It': 6,
#          'oil': 6,
#          'Revs': 6,
#          'new': 6,
#          'NET': 6,
#          'stock': 6,
#          'one': 6,
#          'net': 6,
#          'per': 6,
#          'He': 5,
#          'yen': 5,
#          'today': 5,
#          'rates': 5,
#          'meeting': 5,
#          'other': 5,
#          'could': 5,
#          'bank': 5,
#          'expected': 5,
#          'A': 5,
#          'interest': 5,
#          'two': 5,
#          'current': 5,
#          'after': 5,
#          'rate': 5,
#          'agreement': 5,
#          'their': 5,
#          'report': 5,
#          'against': 5,
#          'May': 5,
#          'no': 5,
#          '1ST': 5,
#          'told': 5,
#          'business': 5,
#          ':': 5,
#          'sales': 5,
#          'But': 5,
#          'some': 5,
#          'price': 5,
#          'United': 4,
#          'spokesman': 4,
#          'March': 4,
#          'reported': 4,
#          'total': 4,
#          '31': 4,
#          'Bank': 4,
#          'currency': 4,
#          '10': 4,
#          'Paris': 4,
#          'foreign': 4,
#          'government': 4,
#          'around': 4,
#          'statement': 4,
#          'into': 4,
#          'week': 4,
#          'NOTE': 4,
#          'added': 4,
#          'marks': 4,
#          'West': 4,
#          'due': 4,
#          '20': 4,
#          'They': 4,
#          'central': 4,
#          'because': 4,
#          '28': 4,
#          'five': 4,
#          'February': 4,
#          'over': 4,
#          'between': 4,
#          'further': 4,
#          'prices': 4,
#          'economic': 4,
#          'growth': 4,
#          'yesterday': 4,
#          'three': 4,
#          'INC': 4,
#          'markets': 4,
#          'major': 4,
#          'Group': 4,
#          'exchange': 4,
#          'sources': 4,
#          'only': 4,
#          'IN': 4,
#          'Japanese': 4,
#          'deficit': 4,
#          'agreed': 4,
#          'Ltd': 4,
#          '30': 4,
#          'products': 4,
#          '1985': 4,
#          'days': 4,
#          'earnings': 4,
#          'when': 4,
#          'do': 3,
#          'months': 3,
#          'exports': 3,
#          'may': 3,
#          'export': 3,
#          'since': 3,
#          'analysts': 3,
#          'guilders': 3,
#          '-': 3,
#          'CTS': 3,
#          'increase': 3,
#          'rise': 3,
#          'Co': 3,
#          'CORP': 3,
#          'tender': 3,
#          'sugar': 3,
#          'shareholders': 3,
#          'operations': 3,
#          'production': 3,
#          'money': 3,
#          'dlr': 3,
#          'including': 3,
#          'take': 3,
#          'still': 3,
#          'through': 3,
#          'American': 3,
#          'Avg': 3,
#          'June': 3,
#          'crop': 3,
#          'out': 3,
#          'should': 3,
#          'before': 3,
#          'compared': 3,
#          'record': 3,
#          'National': 3,
#          'estimated': 3,
#          'levels': 3,
#          'rose': 3,
#          'we': 3,
#          'lower': 3,
#          'communique': 3,
#          'there': 3,
#          'talks': 3,
#          'world': 3,
#          'seven': 3,
#          '15': 3,
#          'years': 3,
#          'domestic': 3,
#          'German': 3,
#          'common': 3,
#          'all': 3,
#          'economy': 3,
#          'wheat': 3,
#          'debt': 3,
#          'policy': 3,
#          'capital': 3,
#          'States': 3,
#          'period': 3,
#          'sale': 3,
#          'Canada': 3,
#          'dividend': 3,
#          'banks': 3,
#          'G-7': 3,
#          'profits': 3,
#          'prior': 3,
#          "'": 3,
#          'European': 3,
#          'dealers': 3,
#          'month': 3,
#          'shrs': 3,
#          'down': 3,
#          'div': 3,
#          'say': 3,
#          'earlier': 3,
#          'made': 3,
#          'acquisition': 3,
#          'EC': 3,
#          'any': 3,
#          'demand': 3,
#          'if': 3,
#          'Reuters': 3,
#          'accord': 3,
#          'next': 3,
#          '22': 3,
#          'imports': 3,
#          'International': 3,
#          'SAYS': 3,
#          'Bundesbank': 3,
#          'trading': 3,
#          'Minister': 3,
#          'We': 3,
#          'traders': 3,
#          'end': 3,
#          'while': 3,
#          'now': 3,
#          'time': 3,
#          'Agriculture': 3,
#          'under': 3,
#          'officials': 3,
#          'board': 3,
#          'investment': 3,
#          'group': 3,
#          'chairman': 3,
#          'countries': 3,
#          'problems': 2,
#          'credit': 2,
#          'FOR': 2,
#          'companies': 2,
#          'largest': 2,
#          'Reserve': 2,
#          'much': 2,
#          'them': 2,
#          'outstanding': 2,
#          '--': 2,
#          '24': 2,
#          'FEB': 2,
#          'support': 2,
#          'target': 2,
#          'New': 2,
#          'bankers': 2,
#          'so': 2,
#          'December': 2,
#          'Oper': 2,
#          'South': 2,
#          'francs': 2,
#          'OF': 2,
#          'AND': 2,
#          'CO': 2,
#          'bought': 2,
#          'SEES': 2,
#          'Seven': 2,
#          'sold': 2,
#          'despite': 2,
#          'intervention': 2,
#          '1986/87': 2,
#          'such': 2,
#          'owned': 2,
#          'reached': 2,
#          'lead': 2,
#          'noted': 2,
#          'four': 2,
#          'move': 2,
#          'what': 2,
#          'operating': 2,
#          'Sales': 2,
#          'fell': 2,
#          'Exchange': 2,
#          'buy': 2,
#          '60': 2,
#          'surplus': 2,
#          'recent': 2,
#          'U.S': 2,
#          'reduce': 2,
#          'gas': 2,
#          'securities': 2,
#          'decline': 2,
#          'meet': 2,
#          'likely': 2,
#          'approved': 2,
#          'Company': 2,
#          '1': 2,
#          'Pay': 2,
#          'plan': 2,
#          'within': 2,
#          'Australia': 2,
#          'Qtly': 2,
#          'too': 2,
#          'paid': 2,
#          '27': 2,
#          'businesses': 2,
#          'financial': 2,
#          'each': 2,
#          'close': 2,
#          'less': 2,
#          'later': 2,
#          'industrial': 2,
#          'long': 2,
#          'DLRS': 2,
#          'DIVIDEND': 2,
#          'NIL': 2,
#          'tax': 2,
#          'ended': 2,
#          'buying': 2,
#          'just': 2,
#          'very': 2,
#          'value': 2,
#          'well': 2,
#          'purchase': 2,
#          'sell': 2,
#          'Finance': 2,
#          'held': 2,
#          'Industries': 2,
#          'ministry': 2,
#          'whether': 2,
#          'set': 2,
#          'chemical': 2,
#          'ago': 2,
#          'income': 2,
#          'revenues': 2,
#          'higher': 2,
#          '50': 2,
#          'supply': 2,
#          'Trade': 2,
#          '12': 2,
#          'position': 2,
#          'did': 2,
#          'basis': 2,
#          "n't": 2,
#          'include': 2,
#          'restructuring': 2,
#          'number': 2,
#          'most': 2,
#          'already': 2,
#          'Federal': 2,
#          'range': 2,
#          'French': 2,
#          'Commission': 2,
#          'average': 2,
#          'unit': 2,
#          'cut': 2,
#          'half': 2,
#          'unchanged': 2,
#          'grain': 2,
#          'VS': 2,
#          'plans': 2,
#          'output': 2,
#          'past': 2,
#          'issue': 2,
#          '4TH': 2,
#          'stocks': 2,
#          'U.K.': 2,
#          'proposed': 2,
#          'This': 2,
#          'reserves': 2,
#          '100': 2,
#          'Germany': 2,
#          'Louvre': 2,
#          'during': 2,
#          'expects': 2,
#          'high': 2,
#          'subsidiary': 2,
#          'can': 2,
#          'January': 2,
#          'losses': 2,
#          'fall': 2,
#          'Department': 2,
#          'Canadian': 2,
#          'weeks': 2,
#          'being': 2,
#          'here': 2,
#          'official': 2,
#          'MLN': 2,
#          'Year': 2,
#          'increased': 2,
#          'issued': 2,
#          'I': 2,
#          'SHR': 2,
#          'split': 2,
#          'several': 2,
#          'acquired': 2,
#          'ministers': 2,
#          'offer': 2,
#          'open': 2,
#          '14': 2,
#          'strong': 2,
#          'Plc': 2,
#          'London': 2,
#          'country': 2,
#          'nine': 2,
#          'previous': 2,
#          'industry': 2,
#          'adjusted': 2,
#          'result': 2,
#          'account': 2,
#          'tonne': 2,
#          'monetary': 2,
#          'annual': 2,
#          '40': 2,
#          'public': 2,
#          'cash': 2,
#          'another': 2,
#          'gain': 2,
#          'Brazil': 2,
#          'budget': 2,
#          'Washington': 2,
#          'early': 2,
#          'however': 2,
#          'LOSS': 2,
#          'six': 2,
#          'continue': 2,
#          'China': 2,
#          'Record': 2,
#          'our': 2,
#          'loan': 2,
#          'includes': 2,
#          'ON': 2,
#          'currencies': 2,
#          'change': 2,
#          'results': 2,
#          'nations': 2,
#          'There': 2,
#          'TRADE': 2,
#          '17': 2,
#          'level': 2,
#          'fiscal': 2,
#          'terms': 2,
#          'mths': 2,
#          'off': 2,
#          'Italian': 1,
#          'boost': 1,
#          '19': 1,
#          '1.5': 1,
#          'significant': 1,
#          'Indonesia': 1,
#          'give': 1,
#          'Komatsu': 1,
#          'pretax': 1,
#          'soon': 1,
#          'Distillers': 1,
#          'Assets': 1,
#          'lot': 1,
#          'crops': 1,
#          'figures': 1,
#          'morning': 1,
#          'present': 1,
#          'AG': 1,
#          'tomorrow': 1,
#          'de': 1,
#          'General': 1,
#          'growing': 1,
#          'you': 1,
#          'without': 1,
#          'Heineken': 1,
#          'asked': 1,
#          'meetings': 1,
#          'short-term': 1,
#          'raw': 1,
#          'show': 1,
#          'date': 1,
#          'Chemical': 1,
#          'agreements': 1,
#          'cause': 1,
#          'does': 1,
#          'GRAIN': 1,
#          'BUYS': 1,
#          'RATE': 1,
#          'reduced': 1,
#          'funds': 1,
#          'third': 1,
#          'improved': 1,
#          'Poehl': 1,
#          'repurchase': 1,
#          'comment': 1,
#          'action': 1,
#          'drop': 1,
#          'Note': 1,
#          'long-term': 1,
#          'dispute': 1,
#          'Malaysia': 1,
#          'welcomed': 1,
#          'officers': 1,
#          'workers': 1,
#          'provided': 1,
#          'full': 1,
#          'coffee': 1,
#          'amount': 1,
#          'Industry': 1,
#          'AEGON': 1,
#          '1988': 1,
#          'restrictions': 1,
#          '42': 1,
#          'question': 1,
#          'MARCH': 1,
#          'TONNES': 1,
#          'ahead': 1,
#          'offered': 1,
#          'NEW': 1,
#          'North': 1,
#          'reserve': 1,
#          'member': 1,
#          'merger': 1,
#          'August': 1,
#          'FED': 1,
#          'dealer': 1,
#          '49': 1,
#          'pay': 1,
#          'OIL': 1,
#          'division': 1,
#          'press': 1,
#          'James': 1,
#          'building': 1,
#          'Morgan': 1,
#          'adding': 1,
#          'York': 1,
#          'general': 1,
#          'materials': 1,
#          'Stoltenberg': 1,
#          '73': 1,
#          'stabilize': 1,
#          'Holdings': 1,
#          'SAVINGS': 1,
#          'sees': 1,
#          'transactions': 1,
#          'progress': 1,
#          'both': 1,
#          'keep': 1,
#          '6': 1,
#          'local': 1,
#          'Swiss': 1,
#          'state': 1,
#          'get': 1,
#          'stimulate': 1,
#          'RTZ': 1,
#          'taxes': 1,
#          'chief': 1,
#          'Party': 1,
#          '2ND': 1,
#          'weather': 1,
#          'Dealers': 1,
#          'additional': 1,
#          'As': 1,
#          'Community': 1,
#          'conference': 1,
#          'reduction': 1,
#          'cocoa': 1,
#          'Miyazawa': 1,
#          'economies': 1,
#          '145': 1,
#          'region': 1,
#          'broadly': 1,
#          'currently': 1,
#          'future': 1,
#          'assets': 1,
#          'takeover': 1,
#          'think': 1,
#          'recently': 1,
#          'Schlesinger': 1,
#          'slightly': 1,
#          'program': 1,
#          'private': 1,
#          'start': 1,
#          'making': 1,
#          'Atlas': 1,
#          'same': 1,
#          'cuts': 1,
#          'Britain': 1,
#          'Lex': 1,
#          'daily': 1,
#          'British': 1,
#          'MARKET': 1,
#          'Analysts': 1,
#          'little': 1,
#          'effort': 1,
#          'above': 1,
#          'hold': 1,
#          'costs': 1,
#          'Williams': 1,
#          'To': 1,
#          'Volcker': 1,
#          'SAID': 1,
#          'expand': 1,
#          'improve': 1,
#          'confirmed': 1,
#          'modest': 1,
#          'positions': 1,
#          'Fund': 1,
#          'far': 1,
#          'Current': 1,
#          'named': 1,
#          'AT': 1,
#          'among': 1,
#          'warrants': 1,
#          'WHEAT': 1,
#          'SEEN': 1,
#          'believe': 1,
#          'Hong': 1,
#          'If': 1,
#          'lost': 1,
#          'Daily': 1,
#          'Steel': 1,
#          'bid': 1,
#          'investor': 1,
#          'small': 1,
#          'planned': 1,
#          'charge': 1,
#          'outcome': 1,
#          'series': 1,
#          'failure': 1,
#          'former': 1,
#          '5.00': 1,
#          'La': 1,
#          'food': 1,
#          'back': 1,
#          'started': 1,
#          'MAY': 1,
#          'Energy': 1,
#          'minimum': 1,
#          'produce': 1,
#          'substantial': 1,
#          'few': 1,
#          'Foothill': 1,
#          'rebate': 1,
#          'prospects': 1,
#          'E.F.': 1,
#          'PROFIT': 1,
#          'Soviet': 1,
#          'director': 1,
#          'people': 1,
#          'term': 1,
#          'cost': 1,
#          'producer': 1,
#          'Last': 1,
#          'required': 1,
#          '1985/86': 1,
#          '0': 1,
#          'need': 1,
#          'Six': 1,
#          'certain': 1,
#          'unlikely': 1,
#          'ACQUISITION': 1,
#          'eight': 1,
#          'NO': 1,
#          'TALKS': 1,
#          'discussed': 1,
#          'holding': 1,
#          'notes': 1,
#          '130': 1,
#          'Electric': 1,
#          'GROUP': 1,
#          'information': 1,
#          'BANK': 1,
#          'Proxmire': 1,
#          'probably': 1,
#          'sharp': 1,
#          'decision': 1,
#          'expectations': 1,
#          'maize': 1,
#          'band': 1,
#          'franc': 1,
#          'shipment': 1,
#          'closed': 1,
#          'San': 1,
#          'left': 1,
#          'Association': 1,
#          'affected': 1,
#          'delivery': 1,
#          'enough': 1,
#          'efforts': 1,
#          'expenses': 1,
#          'effective': 1,
#          'Union': 1,
#          'cutting': 1,
#          'producers': 1,
#          'response': 1,
#          'America': 1,
#          'trend': 1,
#          'goods': 1,
#          'Lawson': 1,
#          'Houston': 1,
#          'Monetary': 1,
#          'provide': 1,
#          'states': 1,
#          'FROM': 1,
#          'development': 1,
#          'mainly': 1,
#          'shareholder': 1,
#          'DEFICIT': 1,
#          'And': 1,
#          'October': 1,
#          'who': 1,
#          'Montedison': 1,
#          '67': 1,
#          'until': 1,
#          'rights': 1,
#          'disclosed': 1,
#          'management': 1,
#          'beginning': 1,
#          'increasing': 1,
#          'addition': 1,
#          'interests': 1,
#          'nil': 1,
#          'Spain': 1,
#          'Korea': 1,
#          'UAL': 1,
#          'power': 1,
#          'follows': 1,
#          'yet': 1,
#          'Traders': 1,
#          'programs': 1,
#          'reiterated': 1,
#          'disappointment': 1,
#          'short': 1,
#          'impact': 1,
#          'place': 1,
#          'Celanese': 1,
#          'Clevite': 1,
#          'maximum': 1,
#          'real': 1,
#          'IMF': 1,
#          'sown': 1,
#          'France': 1,
#          'September': 1,
#          'letter': 1,
#          'partners': 1,
#          'discount': 1,
#          'World': 1,
#          'latest': 1,
#          'port': 1,
#          'particularly': 1,
#          'might': 1,
#          'semiconductor': 1,
#          'showed': 1,
#          'No': 1,
#          'B': 1,
#          'nearly': 1,
#          'soybean': 1,
#          '70': 1,
#          'proposal': 1,
#          'traded': 1,
#          'intentions': 1,
#          'Council': 1,
#          'conditions': 1,
#          'below': 1,
#          'near': 1,
#          'political': 1,
#          'changes': 1,
#          'palm': 1,
#          'natural': 1,
#          'make': 1,
#          'Hutton': 1,
#          'placed': 1,
#          'imbalances': 1,
#          'Board': 1,
#          'factors': 1,
#          'two-for-one': 1,
#          'gains': 1,
#          'WITH': 1,
#          'Kong': 1,
#          'went': 1,
#          'raised': 1,
#          'banking': 1,
#          'TENDER': 1,
#          'Burlington': 1,
#          'joint': 1,
#          'ranges': 1,
#          'his': 1,
#          'provisions': 1,
#          'bill': 1,
#          'implementation': 1,
#          'how': 1,
#          'many': 1,
#          'contained': 1,
#          'accounting': 1,
#          'payments': 1,
#          'Baker': 1,
#          'Southmark': 1,
#          'improvement': 1,
#          'PAYOUT': 1,
#          '13': 1,
#          'ruling': 1,
#          '100,000': 1,
#          'SELL': 1,
#          '480': 1,
#          'Government': 1,
#          'Dome': 1,
#          'beef': 1,
#          'QUARTERLY': 1,
#          'declined': 1,
#          '35': 1,
#          'import': 1,
#          'UP': 1,
#          'negotiations': 1,
#          'IT': 1,
#          'put': 1,
#          'needed': 1,
#          'sequestered': 1,
#          'final': 1,
#          'gold': 1,
#          'copper': 1,
#          'Agreement': 1,
#          'free': 1,
#          'tariffs': 1,
#          'PC': 1,
#          'shipments': 1,
#          'undisclosed': 1,
#          'spirits': 1,
#          'opened': 1,
#          'parent': 1,
#          '25': 1,
#          'decided': 1,
#          'able': 1,
#          'name': 1,
#          '80': 1,
#          '26': 1,
#          'EIA': 1,
#          'Tokyo': 1,
#          'want': 1,
#          'investors': 1,
#          'corn': 1,
#          'MITI': 1,
#          'gave': 1,
#          'senior': 1,
#          'data': 1,
#          'connection': 1,
#          'field': 1,
#          '300': 1,
#          'services': 1,
#          'firm': 1,
#          'manufacturing': 1,
#          'continued': 1,
#          'head': 1,
#          'MATURITY': 1,
#          'part': 1,
#          "'re": 1,
#          'generally': 1,
#          'mark': 1,
#          'Santa': 1,
#          'situation': 1,
#          'federal': 1,
#          'ordinary': 1,
#          'sharply': 1,
#          'going': 1,
#          'MONEY': 1,
#          'Sumitomo': 1,
#          'seen': 1,
#          'Michael': 1,
#          'completed': 1,
#          'large': 1,
#          'Ministry': 1,
#          'marketing': 1,
#          'good': 1,
#          'Brands': 1,
#          'details': 1,
#          'lack': 1,
#          'NOT': 1,
#          'similar': 1,
#          'Secretary': 1,
#          'spokeswoman': 1,
#          '46': 1,
#          'selling': 1,
#          '58': 1,
#          'concern': 1,
#          'steady': 1,
#          'Senate': 1,
#          'own': 1,
#          'members': 1,
#          'Europe': 1,
#          'outlined': 1,
#          'estimates': 1,
#          'meat': 1,
#          'Purolator': 1,
#          'Ecus': 1,
#          'STAKE': 1,
#          'Some': 1,
#          'received': 1,
#          'remain': 1,
#          'Miguel': 1,
#          'bags': 1,
#          'according': 1,
#          'outside': 1,
#          'Congress': 1,
#          'MARKETS': 1,
#          'limited': 1,
#          'top': 1,
#          'system': 1,
#          'Continental': 1,
#          'De': 1,
#          'SMC': 1,
#          'followed': 1,
#          'low': 1,
#          'kilos': 1,
#          'JAPAN': 1,
#          'damage': 1,
#          'previously': 1,
#          '16': 1,
#          'began': 1,
#          'stake': 1,
#          '68': 1,
#          'where': 1,
#          'help': 1,
#          '2.4': 1,
#          'round': 1,
#          'risen': 1,
#          'immediate': 1,
#          'developing': 1,
#          'pressure': 1,
#          'On': 1,
#          'package': 1,
#          'use': 1,
#          'Texas': 1,
#          'HAS': 1,
#          'Oil': 1,
#          'speculation': 1,
#          'source': 1,
#          'FIRST': 1,
#          'announced': 1,
#          'order': 1,
#          'saw': 1,
#          'offset': 1,
#          'greater': 1,
#          'least': 1,
#          'textile': 1,
#          'quality': 1,
#          'crude': 1,
#          'seeking': 1,
#          'SHARE': 1,
#          'Economic': 1,
#          'Committee': 1,
#          'turnover': 1,
#          'look': 1,
#          'registered': 1,
#          'firms': 1,
#          'right': 1,
#          '2': 1,
#          'economist': 1,
#          'transaction': 1,
#          'prevent': 1,
#          'For': 1,
#          'second': 1,
#          'figure': 1,
#          'important': 1,
#          'Foreign': 1,
#          'better': 1,
#          ...})

# %% [markdown]
# ### Negative Sampling

# %%
import random

def prepare_sequence(seq, word2index):
    idxs = list(map(lambda w: word2index[w] if word2index.get(w) is not None else word2index["<UNK>"], seq))
    return torch.LongTensor(idxs)

def negative_sampling(targets, unigram_table, k):
    batch_size = targets.size(0)
    neg_samples = []
    for i in range(batch_size):
        nsample = []
        target_index = targets[i].item()
        while len(nsample) < k: # num of sampling
            neg = random.choice(unigram_table)
            if word2index[neg] == target_index:
                continue
            nsample.append(neg)
        neg_samples.append(prepare_sequence(nsample, word2index).view(1, -1))
    return torch.cat(neg_samples)

# %% [markdown]
# ### Testing the negative sampling

# %%
input_batch  = torch.Tensor(input_batch)
target_batch = torch.LongTensor(target_batch)

# %%
target_batch.shape
# Out:
# torch.Size([2, 1])

# %%
input_batch
# Out:
# tensor([[2455.],
#         [6649.]])

# %%
num_neg = 3
negative_sampling(target_batch, unigram_table, num_neg)
# Out:
# tensor([[9280, 7766, 4794],
#         [2255, 3414, 1637]])

# %%
target_batch[1]
# Out:
# tensor([3013])

# %% [markdown]
# ## 4. Model
#
# $$\mathbf{J}_{\text{neg-sample}}(\mathbf{v}_c,o,\mathbf{U})=-\log(\sigma(\mathbf{u}_o^T\mathbf{v}_c))-\sum_{k=1}^K\log(\sigma(-\mathbf{u}_k^T\mathbf{v}_c))$$

# %%
class SkipgramNegSampling(nn.Module):
    
    def __init__(self, vocab_size, emb_size):
        super(SkipgramNegSampling, self).__init__()
        self.embedding_v = nn.Embedding(vocab_size, emb_size) # center embedding
        self.embedding_u = nn.Embedding(vocab_size, emb_size) # out embedding
        self.logsigmoid = nn.LogSigmoid()
                    
    def forward(self, center_words, target_words, negative_words):
        center_embeds = self.embedding_v(center_words) # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words) # [batch_size, 1, emb_size]
        neg_embeds    = -self.embedding_u(negative_words) # [batch_size, num_neg, emb_size]
        
        positive_score = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #[batch_size, 1, emb_size] @ [batch_size, emb_size, 1] = [batch_size, 1, 1] = [batch_size, 1]
        
        negative_score = neg_embeds.bmm(center_embeds.transpose(1, 2))
        #[batch_size, k, emb_size] @ [batch_size, emb_size, 1] = [batch_size, k, 1]
        
        loss = self.logsigmoid(positive_score) + torch.sum(self.logsigmoid(negative_score), 1)
                
        return -torch.mean(loss)
    
    def prediction(self, inputs):
        embeds = self.embedding_v(inputs)
        
        return embeds

# %% [markdown]
# ## 5. Training

# %%
batch_size     = 256 
embedding_size = 100
model          = SkipgramNegSampling(voc_size, embedding_size)
num_neg        = 10 # num of negative sampling

optimizer = optim.Adam(model.parameters(), lr=0.001)

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

import time

# Training
num_epochs = 1000
for epoch in range(num_epochs):
    
    start = time.time()
    
    input_batch, target_batch = random_batch(batch_size, corpus)
    
    #input_batch: [batch_size, 1]
    input_batch = torch.LongTensor(input_batch)
    
    #target_batch: [batch_size, 1]
    target_batch = torch.LongTensor(target_batch)
    
    #negs_batch:   [batch_size, num_neg]
    negs_batch = negative_sampling(target_batch, unigram_table, num_neg)
    
    optimizer.zero_grad()
        
    loss = model(input_batch, target_batch, negs_batch)
    
    end = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start, end)
    
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 100 == 0:
        print(f"Epoch: {epoch + 1} | cost: {loss:.6f} | Time: {end - start:.2f}s")
# Out:
# Epoch: 100 | cost: 44.137939 | Time: 0.39s
# Epoch: 200 | cost: 40.610195 | Time: 0.40s
# Epoch: 300 | cost: 38.706493 | Time: 0.28s
# Epoch: 400 | cost: 36.061687 | Time: 0.65s
# Epoch: 500 | cost: 34.731659 | Time: 0.51s
# Epoch: 600 | cost: 30.346203 | Time: 0.51s
# Epoch: 700 | cost: 33.298504 | Time: 0.35s
# Epoch: 800 | cost: 33.286488 | Time: 0.47s
# Epoch: 900 | cost: 28.263241 | Time: 0.37s
# Epoch: 1000 | cost: 27.501404 | Time: 0.41s
